# %%
import numpy as np

# %%
import cv2 as cv

# %%
from extract_boundaries import ExtractBoundaries

# %%
boundry=ExtractBoundaries(file_path=r"C:\Users\Hp\Downloads\problems\problems\isolated.csv")

# %%
data_triangle=boundry.get_triangle_boundry()
boundry.plot_boundry(data_triangle)
# Out:
# 1 contours are found

# %%
data_square=boundry.get_square_boundry()
boundry.plot_boundry(data_square)
# Out:
# 1 contours are found

# %%
data_circle=boundry.get_circle_boundry()
boundry.plot_boundry(data_circle)
# Out:
# 1 contours are found

# %%
data_semi_circle=boundry.get_semi_circle_boundry()
boundry.plot_boundry(data_semi_circle)
# Out:
# No contours available

# %%
data_eclipse=boundry.get_ellipse_boundry()
boundry.plot_boundry(data_eclipse)
# Out:
# No contours available

# %%
data_star=boundry.get_star_boundry()
boundry.plot_boundry(data_star)
# Out:
# 1 contours are found

# %%
other_shape=boundry.get_other_shapes_boundry()
boundry.plot_boundry(other_shape)
# Out:
# 1 contours are found
